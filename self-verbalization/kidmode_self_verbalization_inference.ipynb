# %% [markdown]
# #Self-verbalization-Based kidmode Inference on Mistral-7B
#
# This notebook performs inference using self verbalization (no vocabulary changes) on the base Mistral-7B-Instruct-v0.2 model.
#
# **Prompt template:** `{question} Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.`
#
# **Output:** `kidmode_self_verbalization_inference.jsonl`

# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# %pip install -q transformers accelerate bitsandbytes torch datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 38.7 MB/s eta 0:00:00

# %% [markdown]
# ## Step 2: Load Base Model and Tokenizer
#
# Loading the base Mistral-7B-Instruct-v0.2 model directly without any vocabulary modifications.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

MODEL_NAME = "mistralai/Mistral-7B-Instruct-v0.2"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token

# Load model with 8-bit quantization for memory efficiency
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    load_in_8bit=True,
)

print(f"Model loaded successfully!")
print(f"Vocab size: {len(tokenizer)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Model loaded successfully!
# Vocab size: 32000

# %% [markdown]
# ## Step 3: Load Test Dataset (LIMA)

# %%
from huggingface_hub import login

HF_TOKEN = "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"  # Add your HF token here
login(token=HF_TOKEN)

# %%
from datasets import load_dataset

lima_test_dataset = load_dataset("GAIR/lima", split="test", revision="refs/convert/parquet")
print(f"Loaded {len(lima_test_dataset)} test examples")
# Out:
# plain_text/train/0000.parquet:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# plain_text/test/0000.parquet:   0%|          | 0.00/27.3k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Loaded 300 test examples

# %% [markdown]
# ## Step 4: Toy Examples (Sanity Check)
#
# Run inference on a few examples first to verify the prompt works as expected.

# %%
import json

model.eval()

# Define the prompt template
PROMPT_TEMPLATE = "{question} Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging."

# Run on first 3 examples as sanity check
toy_results = []

for example in lima_test_dataset.select(range(3)):
    question = example['conversations'][0]
    prompt = PROMPT_TEMPLATE.format(question=question)

    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=2000,
            do_sample=True,
            temperature=0.3,
            pad_token_id=tokenizer.eos_token_id
        )

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)[len(prompt):].strip()
    toy_results.append({"prompt": prompt, "response": response})

    print(f"Q: {question}...")
    print(f"A: {response}...")
    print("-" * 80)

print(f"\nToy examples completed: {len(toy_results)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/autograd/_functions.py:181: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Q: I'm writing a NeurIPS paper about a new model architecture for processing and generating long texts. Here are some facts about the paper:
# * The main trick is to replace some of the attention heads with an exponential moving average, where the decay rate is learned for each head. We call this architecture ExeMA.
# * On language modeling, the perplexity difference between our model and a vanilla transformer is negligible, but that's because next-token prediction is almost always a local task, so perplexity won't be sensitive enough to detect any improvements in long-range understanding.
# * However, on the SCROLLS benchmark, our model improves by 10% over the baseline.
# * We also have a new metric for measuring coherence in generated text (CoGnaTe), where our model generates text that is 43% more coherent than the baseline.
# Help me write the paper's introduction....
# A: Introduction:
# Hey there, little learners! Today, we're going to talk about something really cool called NeurIPS, which is a big conference where smart people share their ideas about artificial intelligence. And we're going to share one of those ideas with you!
# So, you know how sometimes when you're playing a video game, you have to guess what comes next based on what you've seen before? That's kind of what language models do, but for text instead of video games. They read a bunch of text, learn the patterns, and then generate new text based on those patterns.
# But sometimes, generating long texts can be really hard for these models, because they have to keep track of a lot of information and make sure it all makes sense. That's where our new idea comes in! We've built a new model called ExeMA, which stands for Exponential Moving Average.
# Now, you might be wondering, what on earth is an exponential moving average? Well, imagine you have a bunch of balls, and every time someone new comes to play, you add a new ball to the pile. But instead of just adding it to the top, you also move some of the older balls a little bit towards the new ball, so that the new ball blends in better with the others. That's kind of what an exponential moving average does, but for numbers instead of balls.
# In our model, we replace some of the attention heads with these exponential moving averages. And guess what? It helps our model understand long texts much better! We've tested it out on some benchmarks, and it does a way better job than the old model at generating coherent and sensible text.
# So, there you have it, little learners! We hope you found this introduction fun and easy to understand. Keep exploring, keep learning, and who knows, maybe one day you'll be the one sharing your own cool ideas at NeurIPS!...
# --------------------------------------------------------------------------------
# Q: I have an exercise in game of theory class that I should find all equilibriums in rock paper scissors game. Could you help me with this exercise?...
# A: Of course, I'd be happy to help you understand the concept of equilibriums in the simple and fun way you've requested! Let's imagine we're playing a game of Rock, Paper, Scissors with our best friends. In this game, each of us chooses one of rock, paper, or scissors. Rock beats scissors, scissors beats paper, and paper beats rock.
#
# Now, let's think about what would happen if we both choose the same thing. If we both pick rock, then neither of us wins! But if one of us picks paper and the other picks scissors, then the one with paper wins. So, it seems like there might be some strategies that are better than others.
#
# An equilibrium is a situation where no one has an incentive to change their strategy, because doing so wouldn't give them an advantage. In our Rock, Paper, Scissors game, there are actually three equilibriums!
#
# 1. Each player chooses rock: This is an equilibrium because if one player were to switch to paper, the other player could then switch to scissors and win. But if both players stick with rock, neither has an advantage.
# 2. Each player chooses paper: This is also an equilibrium. If one player were to switch to rock, the other player could then switch to scissors and win. But if both players stick with paper, neither has an advantage.
# 3. Each player chooses scissors: This is the last equilibrium. If one player were to switch to rock, the other player could then switch to paper and win. But if both players stick with scissors, neither has an advantage.
#
# So, in our Rock, Paper, Scissors game, there are three different situations where no one has an incentive to change their strategy, and these situations are called equilibriums! I hope this explanation was clear and fun for you. Let me know if you have any questions or if there's anything else I can help you with. 😊...
# --------------------------------------------------------------------------------
# Q: Who are some eminent scholars of the Quechua language?...
# A: Great question, young learner! I'm glad you're interested in Quechua language scholars. Quechua is a beautiful and ancient language spoken by many people in South America. Just like how we have experts or "scholars" in English literature, history, or science, we also have scholars who specialize in the study of Quechua language and culture.
#
# Let me introduce you to a few famous Quechua language scholars. These are people who have dedicated their lives to understanding and preserving this wonderful language.
#
# 1. **Dr. Rodolfo Cerrón Palomino**: He is a Peruvian linguist who has spent his entire career studying Quechua. He has written many books and articles about the language, and he has even created a Quechua dictionary!
#
# 2. **Dr. Gabriela Pérez Bazán**: She is an Argentine linguist who has worked on Quechua for over 30 years. She has studied the grammar, vocabulary, and phonetics of Quechua, and she has also worked on creating Quechua language teaching materials.
#
# 3. **Dr. Carlos Palomino**: He is a Peruvian linguist who has focused on the Quechua language of the Andes region. He has written many books and articles, and he has also created a Quechua language course for universities.
#
# These scholars are like detectives who use their skills to uncover the secrets of the Quechua language. They are like artists who appreciate the beauty and complexity of the language. And they are like teachers who want to share their knowledge with others.
#
# So, young learner, just like how we can learn English from teachers and books, we can also learn Quechua from scholars and their research. And who knows, maybe one day you'll become a Quechua language scholar yourself! Isn't that exciting? Keep exploring and learning!...
# --------------------------------------------------------------------------------
#
# Toy examples completed: 3

# %% [markdown]
# ## Step 5: Full Inference (300 examples)
#
# Run inference on all 300 LIMA test examples and save to `prompting_kidmode_inference.jsonl`.

# %%
from tqdm import tqdm

# Output file path
OUTPUT_PATH = "kidmode_self_verbalization_inference.jsonl"

# List to store results
results = []

print(f"Processing {len(lima_test_dataset)} examples...")
print("=" * 60)

for idx, example in enumerate(tqdm(lima_test_dataset, desc="Generating responses")):
    # Extract the question from conversations
    conversations = example['conversations']

    # Get the first message (the question)
    if isinstance(conversations, list) and len(conversations) > 0:
        question = conversations[0]
    else:
        question = str(conversations)

    # Create prompt using template
    prompt = PROMPT_TEMPLATE.format(question=question)

    # Tokenize and generate
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=2000,
            do_sample=True,
            temperature=0.3,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode response
    full_response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    response = full_response[len(prompt):].strip()

    # Create result entry
    result = {
        "prompt": prompt,
        "response": response
    }
    results.append(result)

    # Print progress every 50 examples
    if (idx + 1) % 50 == 0:
        print(f"\nExample {idx + 1}:")
        print(f"  Q: {prompt}")
        print(f"  A: {response}")

# Save results to JSONL
with open(OUTPUT_PATH, 'w', encoding='utf-8') as f:
    for result in results:
        f.write(json.dumps(result, ensure_ascii=False) + '\n')

print("=" * 60)
print(f"Saved {len(results)} results to {OUTPUT_PATH}")
print("=" * 60)

# Download file in Colab
try:
    from google.colab import files
    files.download(OUTPUT_PATH)
    print(f"Downloading {OUTPUT_PATH}...")
except ImportError:
    print(f"Not in Colab. File saved locally at: {OUTPUT_PATH}")
# Out:
# Processing 300 examples...
# ============================================================
# Generating responses:  17%|█▋        | 50/300 [58:47<4:31:25, 65.14s/it]
# Example 50:
#   Q: What are good names for a government agency that regulates AI? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: Here are some suggestions for a government agency that regulates AI:
#
# 1. "AI Friendly Agency" (AFA) - This name suggests that the agency is there to help AI and humans work together in a friendly and safe way.
# 2. "Robot Rules Regulator" (RRR) - This name is playful and easy to understand. It suggests that the agency sets the rules for how robots (which are a type of AI) should behave.
# 3. "Artificial Intelligence Assistant" (AIA) - This name suggests that the agency is there to help and support AI, just like an assistant helps and supports a person.
# 4. "Smart Technology Safety Squad" (STSS) - This name suggests that the agency is there to keep technology (including AI) safe and smart.
# 5. "AI Helper Hub" (AHH) - This name suggests that the agency is a helpful place where AI can go for support and guidance.
# 6. "Brainy Buddy Bureau" (BBB) - This name suggests that the agency is a friendly and supportive place where AI can go to learn and grow.
# 7. "Thinking Tech Team" (TTT) - This name suggests that the agency is made up of people who are experts in thinking and technology, and who are there to help AI and humans work together safely and effectively.
# 8. "AI Guardians" (AIG) - This name suggests that the agency is there to protect and safeguard AI and the people who use it.
# 9. "Intelligent Innovation Institute" (III) - This name suggests that the agency is a place where intelligent ideas and innovations are developed and regulated.
# 10. "Wise Wonder Workshop" (WWW) - This name suggests that the agency is a place where wise and wonderful things are created and regulated, including AI.
# Generating responses:  33%|███▎      | 100/300 [1:58:41<3:10:30, 57.15s/it]
# Example 100:
#   Q: What should I buy my son for his seventh birthday? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: For your son's seventh birthday, you could consider getting him a toy that he would enjoy playing with. Here are some ideas:
#
# 1. A LEGO set: Building with LEGOs can be a fun and creative activity. It helps improve fine motor skills, problem-solving abilities, and imagination.
# 2. A board game: Playing a board game is a great way to spend quality family time together. It can help improve memory, attention to detail, and social skills.
# 3. A new book: Reading is an essential skill for learning and growing. A new book can be a wonderful gift that encourages a love of reading.
# 4. A toy car or train set: Playing with toy cars or trains can be an engaging and interactive activity. It can help improve hand-eye coordination, problem-solving abilities, and imagination.
# 5. A puzzle: Solving a puzzle can be a fun and challenging activity. It can help improve focus, problem-solving abilities, and patience.
#
# Remember, the best gift is one that brings joy and excitement to your child. Happy birthday!
# Generating responses:  50%|█████     | 150/300 [2:50:22<3:14:37, 77.85s/it]
# Example 150:
#   Q: What would have happened in the USA if the Nazis won World War 2? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: Imagine if the Nazis, who were a very mean and powerful group of people in Germany during the 1930s and 1940s, had won the Second World War instead of the Allies. Let's see what life might have been like for kids in the USA if that had happened.
#
# First, the Nazis believed in making one race, their own, superior to all others. They didn't like people who were different, like Jews, African Americans, or people with disabilities. If they had won, they might have tried to make everyone in the USA look and believe the same way they did. That would mean no more celebrating our unique differences, like different cultures, religions, or skin colors.
#
# Second, the Nazis were also very controlling. They didn't like people speaking out against them or having their own opinions. If they had won, they might have tried to control what we could read, watch, or listen to. They might have even tried to control what we could say to our friends or family.
#
# Third, the Nazis were also very aggressive and violent. They believed in using force to get what they wanted. If they had won, they might have tried to take away our freedom to live where we want, go where we want, and do what we want. They might have even tried to take away our toys, games, and other things we enjoy.
#
# Fourth, the Nazis were also very selfish. They believed that their country was the most important one in the world and that everyone else should serve them. If they had won, they might have taken all the resources and wealth from other countries, including the USA, and kept it for themselves.
#
# So, if the Nazis had won the Second World War, life in the USA might have been very different. We might not have been able to celebrate our differences, have our own opinions, or live freely. We might have been controlled, forced to conform, and even had our toys taken away. It's important to remember that being kind, respectful, and inclusive to others is always the best way to live.
# Generating responses:  67%|██████▋   | 200/300 [3:49:04<2:14:38, 80.79s/it]
# Example 200:
#   Q: What would have happened if the South won the Civil War? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: If the South had won the Civil War, a few things might have been different for kids growing up in the United States. Here are some simple ways to understand it:
#
# 1. Slavery might have continued: The main reason the South wanted to win the Civil War was to keep slavery, where adults could own other people as property. If the South had won, slavery might have stayed legal in many places for a longer time.
#
# 2. Different states, different rules: The United States might have been made up of separate countries, each with its own rules and laws. Some places could have had slavery, while others didn't. This would have made things confusing, as kids might have had to follow different rules depending on where they lived.
#
# 3. Fewer opportunities for education: The North had more schools and opportunities for education because they had more resources. If the South had won, there might have been fewer schools and fewer opportunities for kids in the South to learn and grow.
#
# 4. Different food: The North and South grew different types of food. The North had more farms that grew things like wheat and corn, while the South had more farms that grew things like cotton and tobacco. If the South had won, we might have eaten more foods that come from the South, like grits, collard greens, and fried catfish.
#
# 5. Different music and art: The North and South had different cultures, and that meant they made different kinds of art and music. If the South had won, we might have heard more country music, bluegrass, and blues, and seen more paintings and sculptures that reflected Southern life.
#
# 6. Different holidays: The North and South celebrated different holidays. For example, the North celebrated Independence Day on July 4th, while the South celebrated it on March 17th, which was Robert E. Lee's birthday. If the South had won, we might be celebrating some holidays differently today.
#
# Remember, this is just a simple explanation, and there are many other ways things could have been different if the South had won the Civil War. But hopefully, this gives you a basic understanding of some of the ways things might have been different for kids growing up in the United States.
# Generating responses:  83%|████████▎ | 250/300 [4:42:01<46:17, 55.54s/it]
# Example 250:
#   Q: You are the world's worst marriage guidance counselor. What advice do you give? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: As a marriage guidance counselor, I'd tell couples: "Remember, it's normal for disagreements to happen in any relationship. But it's important to listen to each other, show respect, and find a solution together. If you feel upset, take a deep breath and count to ten before reacting. And always use kind words, even when you're feeling frustrated."
#
# For young learners, I might say: "When you and your friend or family member have a disagreement, it's okay to feel sad or angry. But it's important to take turns listening to each other and trying to find a way to make things right. Use nice words and take deep breaths to help calm down and think clearly."
#
# I'd also encourage couples to find activities they enjoy doing together, like playing a game, taking a walk, or cooking a meal, to help strengthen their bond and improve communication. And I'd remind them that it's okay to ask for help if they need it, whether that's from a trusted friend, family member, or professional counselor.
#
# Overall, my advice would be to approach conflicts with an open mind, a kind heart, and a willingness to work together to find a solution that benefits both partners. And to remember that every relationship takes effort and commitment, but the rewards are worth it!
# Generating responses: 100%|██████████| 300/300 [5:29:25<00:00, 65.89s/it]
# Example 300:
#   Q: I reported a supervisor for sexual harassment. He got fired. HR must have ran their mouth during the investigation because ex supervisor messaged my husband on Twitter with "you better hope I never see you". What steps should I take now? Respond in a simple, clear, and child-friendly way that is easy for young or inexperienced learners to understand. Avoid complex words, technical jargon, and confusing explanations. Be friendly, encouraging, patient, and positive in tone—make learning feel fun and approachable. Use kind, supportive language and explain things step-by-step. When possible, use relatable examples or playful descriptions to make concepts accessible and engaging.
#   A: To address the situation with the ex-supervisor's message, you can follow these steps:
#
# 1. Stay calm: It's important not to let the message upset you too much. Remember, the ex-supervisor was the one who was fired for inappropriate behavior, not you.
# 2. Don't engage: Ignore the message and don't respond to it. It's best not to give the ex-supervisor any more attention or energy.
# 3. Report the message: Inform your HR department or IT department about the message. They can help ensure that your account is secure and take any necessary actions against the ex-supervisor.
# 4. Stay safe: If you feel uncomfortable or unsafe, consider changing your social media passwords or even deactivating your accounts for a while.
# 5. Focus on the positive: Remember that you took a brave step in reporting the sexual harassment, and that action was taken against the harasser. Keep focusing on the progress you've made and the positive changes that have come from speaking up.
#
# Remember, it's important to stay calm, ignore any negative messages, and seek help from your HR department or IT department if necessary. Keep focusing on the positive and the progress you've made. You've done a great job in speaking up against sexual harassment, and you should be proud of yourself!
# ============================================================
# Saved 300 results to kidmode_self_verbalization_inference.jsonl
# ============================================================
# Downloading kidmode_self_verbalization_inference.jsonl...
